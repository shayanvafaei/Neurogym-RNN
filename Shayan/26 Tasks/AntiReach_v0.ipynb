# %%
# Install gym
! pip install gym
# Install neurogym
! git clone https://github.com/gyyang/neurogym.git
# %cd neurogym/
! pip install -e '.[all]'
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym) (0.0.8)
# Cloning into 'neurogym'...
# remote: Enumerating objects: 10956, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 10956 (delta 69), reused 110 (delta 56), pack-reused 10827
# Receiving objects: 100% (10956/10956), 8.16 MiB | 13.76 MiB/s, done.
# Resolving deltas: 100% (8255/8255), done.
# /content/neurogym
# Obtaining file:///content/neurogym
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from neurogym==0.0.2) (1.23.5)
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (from neurogym==0.0.2) (0.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from neurogym==0.0.2) (3.7.1)
# Collecting psychopy (from neurogym==0.0.2)
#   Downloading psychopy-2023.2.3.tar.gz (35.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 38.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym->neurogym==0.0.2) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym->neurogym==0.0.2) (0.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurogym==0.0.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurogym==0.0.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurogym==0.0.2) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurogym==0.0.2) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurogym==0.0.2) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurogym==0.0.2) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurogym==0.0.2) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurogym==0.0.2) (2.8.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (1.11.3)
# Collecting pyglet==1.5.27 (from psychopy->neurogym==0.0.2)
#   Downloading pyglet-1.5.27-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 47.5 MB/s eta 0:00:00
# Collecting pyqt5 (from psychopy->neurogym==0.0.2)
#   Downloading PyQt5-5.15.10-cp37-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 66.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (1.5.3)
# Collecting questplus>=2023.1 (from psychopy->neurogym==0.0.2)
#   Downloading questplus-2023.1-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (3.1.2)
# Collecting xmlschema (from psychopy->neurogym==0.0.2)
#   Downloading xmlschema-2.5.0-py3-none-any.whl (395 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.0/395.0 kB 37.4 MB/s eta 0:00:00
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (0.12.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (2.31.6)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (0.4.9)
# Collecting psychtoolbox (from psychopy->neurogym==0.0.2)
#   Downloading psychtoolbox-3.0.19.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 90.7 MB/s eta 0:00:00
# Collecting gevent (from psychopy->neurogym==0.0.2)
#   Downloading gevent-23.9.1-cp310-cp310-manylinux_2_28_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 55.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (5.9.5)
# Requirement already satisfied: pyzmq>=22.2.1 in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (23.2.1)
# Collecting ujson (from psychopy->neurogym==0.0.2)
#   Downloading ujson-5.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (1.0.7)
# Collecting msgpack-numpy (from psychopy->neurogym==0.0.2)
#   Downloading msgpack_numpy-0.4.8-py2.py3-none-any.whl (6.9 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (6.0.1)
# Collecting freetype-py (from psychopy->neurogym==0.0.2)
#   Downloading freetype_py-2.4.0-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 59.2 MB/s eta 0:00:00
# Collecting python-bidi (from psychopy->neurogym==0.0.2)
#   Downloading python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Collecting arabic-reshaper (from psychopy->neurogym==0.0.2)
#   Downloading arabic_reshaper-3.0.0-py3-none-any.whl (20 kB)
# Collecting javascripthon (from psychopy->neurogym==0.0.2)
#   Downloading javascripthon-0.12-py3-none-any.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 64.3 MB/s eta 0:00:00
# Collecting websockets (from psychopy->neurogym==0.0.2)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 20.9 MB/s eta 0:00:00
# Collecting wxPython>=4.1.1 (from psychopy->neurogym==0.0.2)
#   Downloading wxPython-4.2.1.tar.gz (73.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 MB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (3.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (2.31.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (0.18.3)
# Collecting pypi-search>=1.2.1 (from psychopy->neurogym==0.0.2)
#   Downloading pypi_search-2.0-py3-none-any.whl (7.1 kB)
# Collecting setuptools<=66.1.1 (from psychopy->neurogym==0.0.2)
#   Downloading setuptools-66.1.1-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 92.5 MB/s eta 0:00:00
# Collecting python-gitlab (from psychopy->neurogym==0.0.2)
#   Downloading python_gitlab-4.2.0-py3-none-any.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 21.7 MB/s eta 0:00:00
# Collecting gitpython (from psychopy->neurogym==0.0.2)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 29.9 MB/s eta 0:00:00
# Requirement already satisfied: cryptography in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (41.0.5)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (1.6.3)
# Collecting esprima (from psychopy->neurogym==0.0.2)
#   Downloading esprima-4.0.1.tar.gz (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jedi>=0.16 (from psychopy->neurogym==0.0.2)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 85.4 MB/s eta 0:00:00
# Collecting pyserial (from psychopy->neurogym==0.0.2)
#   Downloading pyserial-3.5-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 16.1 MB/s eta 0:00:00
# Collecting pyparallel (from psychopy->neurogym==0.0.2)
#   Downloading pyparallel-0.2.2-py3-none-any.whl (38 kB)
# Collecting ffpyplayer (from psychopy->neurogym==0.0.2)
#   Downloading ffpyplayer-4.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (4.8.0.76)
# Collecting python-vlc>=3.0.12118 (from psychopy->neurogym==0.0.2)
#   Downloading python_vlc-3.0.20123-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 13.4 MB/s eta 0:00:00
# Collecting python-xlib (from psychopy->neurogym==0.0.2)
#   Downloading python_xlib-0.33-py2.py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.2/182.2 kB 29.4 MB/s eta 0:00:00
# Requirement already satisfied: tables in /usr/local/lib/python3.10/dist-packages (from psychopy->neurogym==0.0.2) (3.8.0)
# Collecting dukpy (from javascripthon->psychopy->neurogym==0.0.2)
#   Downloading dukpy-0.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 129.8 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->psychopy->neurogym==0.0.2) (0.8.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3->psychopy->neurogym==0.0.2) (2023.3.post1)
# Requirement already satisfied: beautifulsoup4>=4.9.2 in /usr/local/lib/python3.10/dist-packages (from pypi-search>=1.2.1->psychopy->neurogym==0.0.2) (4.11.2)
# Collecting html2text>=2020.1.16 (from pypi-search>=1.2.1->psychopy->neurogym==0.0.2)
#   Downloading html2text-2020.1.16-py3-none-any.whl (32 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->neurogym==0.0.2) (1.16.0)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from questplus>=2023.1->psychopy->neurogym==0.0.2) (2023.7.0)
# Collecting json-tricks (from questplus>=2023.1->psychopy->neurogym==0.0.2)
#   Downloading json_tricks-3.17.3-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->psychopy->neurogym==0.0.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->psychopy->neurogym==0.0.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->psychopy->neurogym==0.0.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->psychopy->neurogym==0.0.2) (2023.7.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse->psychopy->neurogym==0.0.2) (0.41.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography->psychopy->neurogym==0.0.2) (1.16.0)
# Collecting zope.event (from gevent->psychopy->neurogym==0.0.2)
#   Downloading zope.event-5.0-py3-none-any.whl (6.8 kB)
# Collecting zope.interface (from gevent->psychopy->neurogym==0.0.2)
#   Downloading zope.interface-6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 33.6 MB/s eta 0:00:00
# Requirement already satisfied: greenlet>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gevent->psychopy->neurogym==0.0.2) (3.0.1)
# Collecting gitdb<5,>=4.0.1 (from gitpython->psychopy->neurogym==0.0.2)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py->psychopy->neurogym==0.0.2) (0.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->psychopy->neurogym==0.0.2) (1.1.0)
# Collecting PyQt5-sip<13,>=12.13 (from pyqt5->psychopy->neurogym==0.0.2)
#   Downloading PyQt5_sip-12.13.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl (338 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.1/338.1 kB 27.2 MB/s eta 0:00:00
# Collecting PyQt5-Qt5>=5.15.2 (from pyqt5->psychopy->neurogym==0.0.2)
#   Downloading PyQt5_Qt5-5.15.2-py3-none-manylinux2014_x86_64.whl (59.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 10.6 MB/s eta 0:00:00
# Collecting requests-toolbelt>=0.10.1 (from python-gitlab->psychopy->neurogym==0.0.2)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: cython>=0.29.21 in /usr/local/lib/python3.10/dist-packages (from tables->psychopy->neurogym==0.0.2) (3.0.5)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.10/dist-packages (from tables->psychopy->neurogym==0.0.2) (2.8.7)
# Requirement already satisfied: blosc2~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from tables->psychopy->neurogym==0.0.2) (2.0.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from tables->psychopy->neurogym==0.0.2) (9.0.0)
# Collecting elementpath<5.0.0,>=4.1.5 (from xmlschema->psychopy->neurogym==0.0.2)
#   Downloading elementpath-4.1.5-py3-none-any.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.4/216.4 kB 33.4 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.9.2->pypi-search>=1.2.1->psychopy->neurogym==0.0.2) (2.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography->psychopy->neurogym==0.0.2) (2.21)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython->psychopy->neurogym==0.0.2)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: psychopy, wxPython, esprima
#   Building wheel for psychopy (pyproject.toml) ... done
#   Created wheel for psychopy: filename=psychopy-2023.2.3-py3-none-any.whl size=37267798 sha256=37f15007fe4aa3538f3bed61ab29a7fd95556e60083465e58bc2bf35b7e0d74e
#   Stored in directory: /root/.cache/pip/wheels/87/36/43/2d4d4ec72c407fe14f92a4b456178f84d057ff35da71185cd4
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for wxPython (setup.py) ... error
#   ERROR: Failed building wheel for wxPython
#   Running setup.py clean for wxPython
#   Building wheel for esprima (setup.py) ... done
#   Created wheel for esprima: filename=esprima-4.0.1-py3-none-any.whl size=62241 sha256=7978660ca7c0a45a704b3a5e47de48e8328f9230c86d754bd009b6f5f200152c
#   Stored in directory: /root/.cache/pip/wheels/7c/ad/8b/afd6e521e6aaea5482b7b4665ff3ce5a92373bd285e7d3a85c
# Successfully built psychopy esprima
# Failed to build wxPython
# ERROR: Could not build wheels for wxPython, which is required to install pyproject.toml-based projects

# %%
import numpy as np
import torch
import torch.nn as nn

import neurogym as ngym

# Environment
task = 'AntiReach-v0'
kwargs = {'dt': 100}
seq_len = 100

# Make supervised dataset
dataset = ngym.Dataset(task, env_kwargs=kwargs, batch_size=16,
                       seq_len=seq_len)
env = dataset.env
ob_size = env.observation_space.shape[0]
act_size = env.action_space.n

# %%
class Net(nn.Module):
    def __init__(self, num_h):
        super(Net, self).__init__()
        self.lstm = nn.LSTM(ob_size, num_h)
        self.linear = nn.Linear(num_h, act_size)

    def forward(self, x):
        out, hidden = self.lstm(x)
        x = self.linear(out)
        return x

device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = Net(num_h=64).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=1e-2)

running_loss = 0.0
for i in range(2000):
    inputs, labels = dataset()
    inputs = torch.from_numpy(inputs).type(torch.float).to(device)
    labels = torch.from_numpy(labels.flatten()).type(torch.long).to(device)

    # zero the parameter gradients
    optimizer.zero_grad()

    # forward + backward + optimize
    outputs = net(inputs)

    loss = criterion(outputs.view(-1, act_size), labels)
    loss.backward()
    optimizer.step()

    # print statistics
    running_loss += loss.item()
    if i % 200 == 199:
        print('{:d} loss: {:0.5f}'.format(i + 1, running_loss / 200))
        running_loss = 0.0

print('Finished Training')
# Out:
# 200 loss: 0.46291
# 400 loss: 0.01403
# 600 loss: 0.00327
# 800 loss: 0.00163
# 1000 loss: 0.00100
# 1200 loss: 0.00067
# 1400 loss: 0.00048
# 1600 loss: 0.00036
# 1800 loss: 0.00027
# 2000 loss: 0.00022
# Finished Training

# %%
# TODO: Make this into a function in neurogym
perf = 0
num_trial = 200
for i in range(num_trial):
    env.new_trial()
    ob, gt = env.ob, env.gt
    ob = ob[:, np.newaxis, :]  # Add batch axis
    inputs = torch.from_numpy(ob).type(torch.float).to(device)

    action_pred = net(inputs)
    action_pred = action_pred.detach().numpy()
    action_pred = np.argmax(action_pred, axis=-1)
    perf += gt[-1] == action_pred[-1, 0]

perf /= num_trial
print('Average performance in {:d} trials'.format(num_trial))
print(perf)
# Out:
# Average performance in 200 trials
# 1.0
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
